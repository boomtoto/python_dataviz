# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # scatter plot

# %%
irisdata = pd.read_csv('C:\\Users\\ADMIN\\Desktop\\Python\\ExRest\\iris.data',header=None) #จะโหลดไฟล์นี้แบบไม่มีหัวตาราง
irisdata
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
setosa_np = irisdata.iloc[:50,:-1].to_numpy()  
setosa_np[:5,:]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1])

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=60)  # s=size

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=setosa_np[:,2])

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=10*setosa_np[:,2])

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=10*setosa_np[:,2],c = 'y') #c=color

# %%
print =(f'max = {max(setosa_np[:,3])}, min = {min(setosa_np[:,3])}')
print
# Out:
# 'max = 0.6, min = 0.1'

# %%
colors = []
for i in setosa_np[:,3]:
    if i <0.15:
        colors.append('b')
    elif i <0.3:
        colors.append('g')
    elif i <0.45:
        colors.append('y')
    else: 
        colors.append('r')
colors
# Out:
# ['g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'y',
#  'y',
#  'g',
#  'g',
#  'b',
#  'g',
#  'g',
#  'b',
#  'b',
#  'g',
#  'y',
#  'y',
#  'y',
#  'y',
#  'y',
#  'g',
#  'y',
#  'g',
#  'r',
#  'g',
#  'g',
#  'y',
#  'g',
#  'g',
#  'g',
#  'g',
#  'y',
#  'b',
#  'g',
#  'b',
#  'g',
#  'g',
#  'b',
#  'g',
#  'g',
#  'y',
#  'y',
#  'g',
#  'r',
#  'y',
#  'y',
#  'g',
#  'g',
#  'g',
#  'g']

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c = colors)

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c =setosa_np[:,3])

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c =setosa_np[:,3],cmap='YlOrBr')

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c = np.array([[1,0.5,0.9]])) #  ผสมสี

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c =setosa_np[:,3],cmap='YlOrBr',marker ='*')
# ดูแบบได้ที่ https://matplotlib.org/3.1.3/api/markers_api.html#module-matplotlib.markers

# %% [markdown]
# # Visualize 2 data ใส่ข้อมูล2อันลง1กราฟ

# %%
versicolor_np = irisdata.iloc[50:100 ,:-1].to_numpy()

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c =setosa_np[:,3],cmap='BuPu',marker ='*')
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2],c =versicolor_np[:,3],cmap='BuPu',marker ='8')

# %% [markdown]
# # Visualize 3 data ใส่ข้อมูล3อันลง1กราฟ

# %%
virginica_np = irisdata.iloc[100: ,:-1].to_numpy()

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c =setosa_np[:,3],cmap='BuPu',marker ='*')
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2],c =versicolor_np[:,3],cmap='BuPu',marker ='8')
plt.scatter(virginica_np[:,0],virginica_np[:,1],s=30*virginica_np[:,2],c =virginica_np[:,3],cmap='BuPu',marker ='+')

# %% [markdown]
# # HW

# %%
plt.scatter(setosa_np[:,1],setosa_np[:,0],s=30*setosa_np[:,2],c =setosa_np[:,3],cmap='RdPu',marker ='*')
plt.scatter(versicolor_np[:,1],versicolor_np[:,0],s=30*versicolor_np[:,2],c =versicolor_np[:,3],cmap='RdPu',marker ='8')
plt.scatter(virginica_np[:,1],virginica_np[:,0],s=30*virginica_np[:,2],c =virginica_np[:,3],cmap='RdPu',marker ='+')

# %%
plt.scatter(setosa_np[:,1],setosa_np[:,0],c =setosa_np[:,3],s=30*setosa_np[:,2],cmap='BuPu',marker ='*')
plt.scatter(versicolor_np[:,1],versicolor_np[:,0],c =versicolor_np[:,3],s=30*versicolor_np[:,2],cmap='BuPu',marker ='8')
plt.scatter(virginica_np[:,1],virginica_np[:,0],c =virginica_np[:,3],s=30*virginica_np[:,2],cmap='BuPu',marker ='+')

# %%
plt.scatter(setosa_np[:,1],setosa_np[:,0],c =setosa_np[:,3],s=30*setosa_np[:,2],marker ='*',cmap='BuPu')
plt.scatter(versicolor_np[:,1],versicolor_np[:,0],c =versicolor_np[:,3],s=30*versicolor_np[:,2],marker ='8',cmap='BuPu')
plt.scatter(virginica_np[:,1],virginica_np[:,0],c =virginica_np[:,3],s=30*virginica_np[:,2],marker ='+',cmap='BuPu')

# %%
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1],c = setosa_np[:,0],cmap='BuPu',marker="*")
plt.scatter(versicolor_np[:,3],versicolor_np [:,2],s=30*versicolor_np[:,1],c = versicolor_np[:,0],cmap='BuPu',marker="8" )
plt.scatter(virginica_np[:,3],virginica_np[:,2],s=30*virginica_np[:,1],c = virginica_np[:,0],cmap='BuPu',marker="+" )

# %%
plt.scatter(setosa_np[:,1],setosa_np[:,2],s=30*setosa_np[:,3],c = setosa_np[:,0],cmap='BuPu',marker="*")
plt.scatter(versicolor_np[:,1],versicolor_np [:,2],s=30*versicolor_np[:,3],c = versicolor_np[:,0],cmap='BuPu',marker="8" )
plt.scatter(virginica_np[:,1],virginica_np[:,2],s=30*virginica_np[:,3],c = virginica_np[:,0],cmap='BuPu',marker="+" )

# %%
from matplotlib import pyplot as plt    #รวมกราฟไว้ด้วยกันใน1output
import matplotlib

# %%
matplotlib.rcParams['figure.figsize']=[13,13]

# %%
plt.subplot(4,2,1)#มี1แถว3ครั้ง รูปที่ 1

plt.scatter(setosa_np[:,2],setosa_np[:,3],s=30*setosa_np[:,0],c = setosa_np[:,1],cmap='RdPu',marker="*")
plt.scatter(versicolor_np[:,2],versicolor_np [:,3],s=30*versicolor_np[:,0],c = versicolor_np[:,1],cmap='RdPu',marker="8" )
plt.scatter(virginica_np[:,2],virginica_np[:,3],s=30*virginica_np[:,0],c = virginica_np[:,1],cmap='RdPu',marker="+" )


plt.subplot(4,2,2)

plt.scatter(setosa_np[:,0],setosa_np[:,2],s=30*setosa_np[:,3],c = setosa_np[:,1],cmap='RdPu',marker="*")
plt.scatter(versicolor_np[:,0],versicolor_np [:,2],s=30*versicolor_np[:,3],c = versicolor_np[:,1],cmap='RdPu',marker="8" )
plt.scatter(virginica_np[:,0],virginica_np[:,2],s=30*virginica_np[:,3],c = virginica_np[:,1],cmap='RdPu',marker="+" )

plt.subplot(4,2,3)

plt.scatter(setosa_np[:,1],setosa_np[:,0],s=30*setosa_np[:,2],c = setosa_np[:,3],cmap='RdPu',marker="*")
plt.scatter(versicolor_np[:,1],versicolor_np [:,0],s=30*versicolor_np[:,2],c = versicolor_np[:,3],cmap='RdPu',marker="8" )
plt.scatter(virginica_np[:,1],virginica_np[:,0],s=30*virginica_np[:,2],c = virginica_np[:,3],cmap='RdPu',marker="+" )



plt.subplot(4,2,4)

plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1],c = setosa_np[:,0],cmap='RdPu',marker="*")
plt.scatter(versicolor_np[:,3],versicolor_np [:,2],s=30*versicolor_np[:,1],c = versicolor_np[:,0],cmap='RdPu',marker="8" )
plt.scatter(virginica_np[:,3],virginica_np[:,2],s=30*virginica_np[:,1],c = virginica_np[:,0],cmap='RdPu',marker="+" )


plt.subplot(4,2,5)
plt.scatter(setosa_np[:,2],setosa_np[:,0],s=30*setosa_np[:,3],c = setosa_np[:,1],cmap='RdPu',marker="*")
plt.scatter(versicolor_np[:,2],versicolor_np [:,0],s=30*versicolor_np[:,3],c = versicolor_np[:,1],cmap='RdPu',marker="8" )
plt.scatter(virginica_np[:,2],virginica_np[:,0],s=30*virginica_np[:,3],c = virginica_np[:,1],cmap='RdPu',marker="+" )

plt.subplot(4,2,6)
plt.scatter(setosa_np[:,0],setosa_np[:,3],s=30*setosa_np[:,2],c = setosa_np[:,1],cmap='RdPu',marker="*")
plt.scatter(versicolor_np[:,0],versicolor_np [:,3],s=30*versicolor_np[:,2],c = versicolor_np[:,1],cmap='RdPu',marker="8" )
plt.scatter(virginica_np[:,0],virginica_np[:,3],s=30*virginica_np[:,2],c = virginica_np[:,1],cmap='RdPu',marker="+" )

plt.subplot(4,2,7)

plt.scatter(setosa_np[:,3],setosa_np[:,0],s=30*setosa_np[:,1],c = setosa_np[:,2],cmap='RdPu',marker="*")
plt.scatter(versicolor_np[:,3],versicolor_np [:,0],s=30*versicolor_np[:,1],c = versicolor_np[:,2],cmap='RdPu',marker="8" )
plt.scatter(virginica_np[:,3],virginica_np[:,0],s=30*virginica_np[:,1],c = virginica_np[:,2],cmap='RdPu',marker="+" )

plt.subplot(4,2,8)


plt.scatter(setosa_np[:,1],setosa_np[:,2],s=30*setosa_np[:,3],c = setosa_np[:,0],cmap='RdPu',marker="*")
plt.scatter(versicolor_np[:,1],versicolor_np [:,2],s=30*versicolor_np[:,3],c = versicolor_np[:,0],cmap='RdPu',marker="8" )
plt.scatter(virginica_np[:,1],virginica_np[:,2],s=30*virginica_np[:,3],c = virginica_np[:,0],cmap='RdPu',marker="+" )

# %% [markdown]
# หมายเหตุ *** plt.subplot(2,4,1) บอกถึง (แถว,หลัก,ตำแหน่ง)

# %% [markdown]
# https://matplotlib.org/3.1.3/api/markers_api.html#module-matplotlib.markers

# %% [markdown]
# https://matplotlib.org/3.1.3/api/_as_gen/matplotlib.pyplot.scatter.html
